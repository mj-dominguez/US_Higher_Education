# %%
import numpy as np 
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

ed = pd.read_csv('US Higher Education Value vs. Vulnerability - dataset.csv', delimiter = ',', header = 0)

# %%
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 31 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    object
#  2   State                                               438 non-null    object
#  3   Ranking List                                        438 non-null    object
#  4   Rank                                                438 non-null    int64
#  5   Rank Pct Rank                                       438 non-null    float64
#  6   Undergraduate Admit Rate                            438 non-null    object
#  7   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
# ...

# %%
ed.rename(columns = {"Value\n(C x E x E)": "Value"}, inplace = True)
ed.head()
# Out:
#       Institution Name Full Time Enrollment State  \
# 0   Adelphi University                6,562    NY
# 1  Agnes Scott College                  998    GA
# 2       Albion College                1,509    MI
# 3    Allegheny College                1,724    PA
# 4  American University               11,435    DC
#
#                       Ranking List  Rank  Rank Pct Rank  \
# 0  USN National University Ranking   166           0.28
# 1     USN National College Ranking    58           0.74
# 2     USN National College Ranking   140           0.38
# 3     USN National College Ranking    82           0.64
# 4  USN National University Ranking    77           0.66
#
#   Undergraduate Admit Rate  Undergraduate Admit Rate Pct Rank  \
# 0                      74%                               0.29
# 1                      70%                               0.38
# 2                      68%                               0.43
# 3                      64%                               0.52
# ...

# %%
ed.drop(columns = 'Ranking List', inplace = True)

# %%
# ed.melt(id_vars=['Institution Name'], value_vars=['Credential Score'])

# %%
a = ed.groupby('Prof G Categorization')
b = a.mean().round(2)

# %%
ed['Full Time Enrollment'] = ed['Full Time Enrollment'].str.replace(',', '').astype(float)

# %%
ed['Undergraduate Admit Rate'] = ed['Undergraduate Admit Rate'].str.rstrip('%').astype('float')/100

# %%
ed['Average Monthly Search Volume'] = ed['Average Monthly Search Volume'].str.replace(',', '').astype(float)

# %%
ed['15-Year NPV'] = ed['15-Year NPV'].str.replace('$','')

# %%
ed['15-Year NPV'] = ed['15-Year NPV'].str.replace(',', '')

# %%
ed['15-Year NPV'] = ed['15-Year NPV'].astype(float)
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
ed['30-Year NPV'] = ed['30-Year NPV'].str.replace('$','')

# %%
ed['30-Year NPV'] = ed['30-Year NPV'].str.replace(',', '')

# %%
ed['30-Year NPV'] = ed['30-Year NPV'].astype(float)
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
ed['Instructional Wages per Full-Time Student'] = ed['Instructional Wages per Full-Time Student'].str.replace('$','')

# %%
ed['Instructional Wages per Full-Time Student'] = ed['Instructional Wages per Full-Time Student'].str.replace(',','')

# %%
ed['Instructional Wages per Full-Time Student'] = ed['Instructional Wages per Full-Time Student'].astype(float)
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
ed['Average Undergraduate Tuition and Fees'] = ed['Average Undergraduate Tuition and Fees'].str.strip('$')

# %%
ed['Average Undergraduate Tuition and Fees'] = ed['Average Undergraduate Tuition and Fees'].str.replace(',', '')

# %%
ed['Average Undergraduate Tuition and Fees'] = ed['Average Undergraduate Tuition and Fees'].astype(float)
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
ed['Endowment per Full Time Student'] = ed['Endowment per Full Time Student'].str.strip('$')
ed['Endowment per Full Time Student'] = ed['Endowment per Full Time Student'].str.replace(',', '')
ed['Endowment per Full Time Student'] = ed['Endowment per Full Time Student'].astype(float)
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
ed['Percentage of International Students'] = ed['Percentage of International Students'].str.rstrip('%').astype('float')/100
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 30 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Institution Name                                    438 non-null    object
#  1   Full Time Enrollment                                438 non-null    float64
#  2   State                                               438 non-null    object
#  3   Rank                                                438 non-null    int64
#  4   Rank Pct Rank                                       438 non-null    float64
#  5   Undergraduate Admit Rate                            438 non-null    float64
#  6   Undergraduate Admit Rate Pct Rank                   438 non-null    float64
#  7   Average Monthly Search Volume                       438 non-null    float64
# ...

# %%
a[['Undergraduate Admit Rate','Experience Score','Instructional Wages per Full-Time Student','Eduation Score','Average Undergraduate Tuition and Fees','Value','Endowment per Full Time Student','Percentage of International Students','Vulnerability Score']].agg([np.median]).round(2)
# Out:
#                       Undergraduate Admit Rate Experience Score  \
#                                         median           median
# Prof G Categorization
# Perish                                    0.66              2.2
# Struggle                                  0.72              2.2
# Survive                                   0.57              2.8
# Thrive                                    0.51              2.8
#
#                       Instructional Wages per Full-Time Student  \
#                                                          median
# Prof G Categorization
# Perish                                                   8554.0
# Struggle                                                 7897.0
# Survive                                                  9844.0
# Thrive                                                  12574.0
#
#                       Eduation Score Average Undergraduate Tuition and Fees  \
# ...

# %%
Perish = ed['Prof G Categorization'] == 'Perish'

# %% [markdown]
# ## Project?

# %%
ax = sns.lmplot(x = 'Endowment per Full Time Student', y = 'Vulnerability Score', data = ed, height = 10, hue = 'Prof G Categorization', 
                palette = ["green", "red", "blue", "purple"], markers = ["x", "+", "o","."], ci = False)
plt.savefig('vulnerablility.png', transparent=True)

# %%
ax = sns.lmplot(x = 'Value', y = 'Vulnerability Score', data = ed, height = 10, hue = 'Prof G Categorization', 
                palette = ["green", "red", "blue", "purple"], markers = ["x", "+", "o","."], ci = False)

# %%
ax = sns.lmplot(x = 'Average Monthly Search Volume', y = 'Vulnerability Score', data = ed, height = 10, hue = 'Prof G Categorization', 
                palette = ["green", "red", "blue", "purple"], markers = ["x", "+", "o","."], ci = False)

# %%
ax = sns.lmplot(x = 'Percentage of International Students', y = 'Vulnerability Score', 
                data = ed, height = 10, hue = 'State', ci = False)

# %%
ed['State'].value_counts().head(3)
# Out:
# NY    39
# PA    36
# CA    31
# Name: State, dtype: int64

# %%
CA = ed['State'] == 'CA'
NY = ed['State'] == 'NY'
PA = ed['State'] == 'PA'
top3 = ed[NY | PA | CA]

# %%
cx = sns.lmplot(x = 'Percentage of International Students', y = 'Vulnerability Score', 
                data = top3, height = 10, hue = 'State', ci = False)

# %%
ax = sns.barplot(x = 'State', y= 'Percentage of International Students', hue = 'Prof G Categorization',data = top3)

# %%
ax = sns.barplot(x = 'State', y= 'Endowment per Full Time Student', hue = 'Prof G Categorization',data = top3)

# %%
ax = sns.barplot(x = 'State', y= 'Average Undergraduate Tuition and Fees', hue = 'Prof G Categorization',data = top3)

# %%
ax = sns.barplot(x = 'State', y= 'Average Monthly Search Volume', hue = 'Prof G Categorization',data = top3)
